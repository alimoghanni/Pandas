# %% [markdown]
# # Pandas Tutorial - Part 2
#
# # Indexes - How to Set, Reset, and Use Indexes
#
# ### Implementation: Ali Moghanni
#
# *Resources:*
#
# This Jupyter notebook can be obtained at [https://github.com/alimoghanni/Pandas](https://github.com/alimoghanni/Pandas).
#
# updated: **2020-04-01**

# %%
# Preamble: useful toolboxes, librairies, functions, etc.

import pandas as pd
import numpy as np

# %%
# Python dictionary

people = {
    "first": ["Agatha", "Hercule","Jane", "David", "Nicholle", "Bruce", "Jacob", "Maggie", "Cristiano"], 
    "last": ["Christie", "Poirot", "Marple", "Tom", "Tom", "Lee", "Gyllenhaal", "Gyllenhaal", "Ronaldo"], 
    "email": ["AgathaChristie@mail.com", "HerculePoirot@mail.com", "NA", "DavidTom@gmail.com", "NicholleTom@gmail.com", "BruceLee@yahoo.com","JacobGyllenhaal@mail.com", "MaggieGyllenhaal@mail.com", "CristianoRonaldo@mail.com"],
    "age": [85, 54, np.nan ,np.nan, 42, 32, 39, 42, 35 ],
    "occupation": ["Novelist","Private investigator", "Amateur detective", "Actor", "Actress", "Martial artist", "Actor", "producer", "footballer"],
    "nationality": ["English", "Belgian", "British", "American", "American", "Chinese", "American", "American", "Portuguese"],
    "born": ["15 September 1890", "Missing", "December 1927", "March 23, 1978", "March 23, 1978", "November 27, 1940", "December 19, 1980", "November 16, 1977", "February 5, 1985"],
    "male": ["No", "Yes", "No", "Yes", "No", "Yes", "Yes", "No", "Yes"]
}

# %%
# Create pandas DataFrame from dictionary

df = pd.DataFrame(people)

df
# Out:
#        first        last                      email   age  \
# 0     Agatha    Christie    AgathaChristie@mail.com  85.0
# 1    Hercule      Poirot     HerculePoirot@mail.com  54.0
# 2       Jane      Marple                         NA   NaN
# 3      David         Tom         DavidTom@gmail.com   NaN
# 4   Nicholle         Tom      NicholleTom@gmail.com  42.0
# 5      Bruce         Lee         BruceLee@yahoo.com  32.0
# 6      Jacob  Gyllenhaal   JacobGyllenhaal@mail.com  39.0
# 7     Maggie  Gyllenhaal  MaggieGyllenhaal@mail.com  42.0
# 8  Cristiano     Ronaldo  CristianoRonaldo@mail.com  35.0
#
#              occupation nationality               born male
# 0              Novelist     English  15 September 1890   No
# 1  Private investigator     Belgian            Missing  Yes
# 2     Amateur detective     British      December 1927   No
# 3                 Actor    American     March 23, 1978  Yes
# 4               Actress    American     March 23, 1978   No
# 5        Martial artist     Chinese  November 27, 1940  Yes
# 6                 Actor    American  December 19, 1980  Yes
# 7              producer    American  November 16, 1977   No
# 8            footballer  Portuguese   February 5, 1985  Yes

# %%
df['first']
# Out:
# 0       Agatha
# 1      Hercule
# 2         Jane
# 3        David
# 4     Nicholle
# 5        Bruce
# 6        Jacob
# 7       Maggie
# 8    Cristiano
# Name: first, dtype: object

# %%
# Set the DataFrame index using existing columns

df.set_index('first', inplace=True)

df
# Out:
#                  last                      email   age            occupation  \
# first
# Agatha       Christie    AgathaChristie@mail.com  85.0              Novelist
# Hercule        Poirot     HerculePoirot@mail.com  54.0  Private investigator
# Jane           Marple                         NA   NaN     Amateur detective
# David             Tom         DavidTom@gmail.com   NaN                 Actor
# Nicholle          Tom      NicholleTom@gmail.com  42.0               Actress
# Bruce             Lee         BruceLee@yahoo.com  32.0        Martial artist
# Jacob      Gyllenhaal   JacobGyllenhaal@mail.com  39.0                 Actor
# Maggie     Gyllenhaal  MaggieGyllenhaal@mail.com  42.0              producer
# Cristiano     Ronaldo  CristianoRonaldo@mail.com  35.0            footballer
#
#           nationality               born male
# first
# Agatha        English  15 September 1890   No
# Hercule       Belgian            Missing  Yes
# Jane          British      December 1927   No
# David        American     March 23, 1978  Yes
# Nicholle     American     March 23, 1978   No
# Bruce         Chinese  November 27, 1940  Yes
# Jacob        American  December 19, 1980  Yes
# Maggie       American  November 16, 1977   No
# Cristiano  Portuguese   February 5, 1985  Yes

# %%
# The index (row labels) of the DataFrame

df.index
# Out:
# Index(['Agatha', 'Hercule', 'Jane', 'David', 'Nicholle', 'Bruce', 'Jacob',
#        'Maggie', 'Cristiano'],
#       dtype='object', name='first')

# %%
df.loc['Hercule']
# Out:
# last                           Poirot
# email          HerculePoirot@mail.com
# age                              54.0
# occupation       Private investigator
# nationality                   Belgian
# born                          Missing
# male                              Yes
# Name: Hercule, dtype: object

# %%
df.loc['Hercule', 'occupation']
# Out:
# 'Private investigator'

# %%
# Sort index

df.sort_index() # inplace=True
# Out:
#                  last                      email   age            occupation  \
# first
# Agatha       Christie    AgathaChristie@mail.com  85.0              Novelist
# Bruce             Lee         BruceLee@yahoo.com  32.0        Martial artist
# Cristiano     Ronaldo  CristianoRonaldo@mail.com  35.0            footballer
# David             Tom         DavidTom@gmail.com   NaN                 Actor
# Hercule        Poirot     HerculePoirot@mail.com  54.0  Private investigator
# Jacob      Gyllenhaal   JacobGyllenhaal@mail.com  39.0                 Actor
# Jane           Marple                         NA   NaN     Amateur detective
# Maggie     Gyllenhaal  MaggieGyllenhaal@mail.com  42.0              producer
# Nicholle          Tom      NicholleTom@gmail.com  42.0               Actress
#
#           nationality               born male
# first
# Agatha        English  15 September 1890   No
# Bruce         Chinese  November 27, 1940  Yes
# Cristiano  Portuguese   February 5, 1985  Yes
# David        American     March 23, 1978  Yes
# Hercule       Belgian            Missing  Yes
# Jacob        American  December 19, 1980  Yes
# Jane          British      December 1927   No
# Maggie       American  November 16, 1977   No
# Nicholle     American     March 23, 1978   No

# %%
df.sort_index(ascending=False)
# Out:
#                  last                      email   age            occupation  \
# first
# Nicholle          Tom      NicholleTom@gmail.com  42.0               Actress
# Maggie     Gyllenhaal  MaggieGyllenhaal@mail.com  42.0              producer
# Jane           Marple                         NA   NaN     Amateur detective
# Jacob      Gyllenhaal   JacobGyllenhaal@mail.com  39.0                 Actor
# Hercule        Poirot     HerculePoirot@mail.com  54.0  Private investigator
# David             Tom         DavidTom@gmail.com   NaN                 Actor
# Cristiano     Ronaldo  CristianoRonaldo@mail.com  35.0            footballer
# Bruce             Lee         BruceLee@yahoo.com  32.0        Martial artist
# Agatha       Christie    AgathaChristie@mail.com  85.0              Novelist
#
#           nationality               born male
# first
# Nicholle     American     March 23, 1978   No
# Maggie       American  November 16, 1977   No
# Jane          British      December 1927   No
# Jacob        American  December 19, 1980  Yes
# Hercule       Belgian            Missing  Yes
# David        American     March 23, 1978  Yes
# Cristiano  Portuguese   February 5, 1985  Yes
# Bruce         Chinese  November 27, 1940  Yes
# Agatha        English  15 September 1890   No

# %%
# Reset the index

df.reset_index(inplace=True)

df
# Out:
#        first        last                      email   age  \
# 0     Agatha    Christie    AgathaChristie@mail.com  85.0
# 1    Hercule      Poirot     HerculePoirot@mail.com  54.0
# 2       Jane      Marple                         NA   NaN
# 3      David         Tom         DavidTom@gmail.com   NaN
# 4   Nicholle         Tom      NicholleTom@gmail.com  42.0
# 5      Bruce         Lee         BruceLee@yahoo.com  32.0
# 6      Jacob  Gyllenhaal   JacobGyllenhaal@mail.com  39.0
# 7     Maggie  Gyllenhaal  MaggieGyllenhaal@mail.com  42.0
# 8  Cristiano     Ronaldo  CristianoRonaldo@mail.com  35.0
#
#              occupation nationality               born male
# 0              Novelist     English  15 September 1890   No
# 1  Private investigator     Belgian            Missing  Yes
# 2     Amateur detective     British      December 1927   No
# 3                 Actor    American     March 23, 1978  Yes
# 4               Actress    American     March 23, 1978   No
# 5        Martial artist     Chinese  November 27, 1940  Yes
# 6                 Actor    American  December 19, 1980  Yes
# 7              producer    American  November 16, 1977   No
# 8            footballer  Portuguese   February 5, 1985  Yes
