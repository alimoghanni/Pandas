# %% [markdown]
# # Pandas Tutorial - Part 10
#
# # Reading/Writing Data to Different Sources - Excel, JSON, SQL, Etc
#
# ### Implementation: Ali Moghanni
#
# *Resources:*
#
# This Jupyter notebook can be obtained at [this address](https://sites.google.com/view/alimoghanni/teaching/python-notebooks).
#
# For any comment regarding this notebook (including typos), please send an email to: ali.moghanni@mat.uc.pt.
#
# updated: **2020-04-02**

# %%
# Preamble: useful toolboxes, librairies, functions, etc.

import pandas as pd
import numpy as np

# %%
# Python dictionary

people = {
    "first": ["Agatha", "Hercule","Jane", "David", "Nicholle", "Bruce", "Jacob", "Maggie", "Cristiano"], 
    "last": ["Christie", "Poirot", "Marple", "Tom", "Tom", "Lee", "Gyllenhaal", "Gyllenhaal", "Ronaldo"], 
    "email": ["AgathaChristie@mail.com", "HerculePoirot@mail.com", np.nan, "DavidTom@gmail.com", "NicholleTom@gmail.com", "BruceLee@yahoo.com","JacobGyllenhaal@mail.com", "MaggieGyllenhaal@mail.com", "CristianoRonaldo@mail.com"],
    "age": ['85', '54', np.nan ,None, '42', 32, 39, 42, 35 ],
    "occupation": ["Novelist","Private investigator", "Amateur detective", "Actor", "Actress", "Martial artist", "NA", "producer", "footballer"],
    "nationality": ["English", "Belgian", "British", "American", "Missing", "Chinese", "American", "American", "Portuguese"],
    "born": ["15 September 1890", "NA", "December 1927", "March 23, 1978", "March 23, 1978", "November 27, 1940", "December 19, 1980", "November 16, 1977", "February 5, 1985"],
    "male": ["No", "Yes", "No", "Yes", np.nan, "Yes", "Yes", "No", "Yes"]
}

# %%
df = pd.DataFrame(people)

df
# Out:
#        first        last                      email   age  \
# 0     Agatha    Christie    AgathaChristie@mail.com    85
# 1    Hercule      Poirot     HerculePoirot@mail.com    54
# 2       Jane      Marple                        NaN   NaN
# 3      David         Tom         DavidTom@gmail.com  None
# 4   Nicholle         Tom      NicholleTom@gmail.com    42
# 5      Bruce         Lee         BruceLee@yahoo.com    32
# 6      Jacob  Gyllenhaal   JacobGyllenhaal@mail.com    39
# 7     Maggie  Gyllenhaal  MaggieGyllenhaal@mail.com    42
# 8  Cristiano     Ronaldo  CristianoRonaldo@mail.com    35
#
#              occupation nationality               born male
# 0              Novelist     English  15 September 1890   No
# 1  Private investigator     Belgian                 NA  Yes
# 2     Amateur detective     British      December 1927   No
# 3                 Actor    American     March 23, 1978  Yes
# 4               Actress     Missing     March 23, 1978  NaN
# 5        Martial artist     Chinese  November 27, 1940  Yes
# 6                    NA    American  December 19, 1980  Yes
# 7              producer    American  November 16, 1977   No
# 8            footballer  Portuguese   February 5, 1985  Yes

# %%
filt = (df['nationality'] == 'American')

american_df = df.loc[filt]

american_df
# Out:
#     first        last                      email   age occupation nationality  \
# 3   David         Tom         DavidTom@gmail.com  None      Actor    American
# 6   Jacob  Gyllenhaal   JacobGyllenhaal@mail.com    39         NA    American
# 7  Maggie  Gyllenhaal  MaggieGyllenhaal@mail.com    42   producer    American
#
#                 born male
# 3     March 23, 1978  Yes
# 6  December 19, 1980  Yes
# 7  November 16, 1977   No

# %%
american_df.to_csv('american_people.csv')

# %%
american_df.to_csv('american_people.tsv', sep='\t')

# %%
# pip install xlwt openpyxl xlrd

# %%
american_df.to_excel('american_people.xlsx')

# %%
test = pd.read_excel('american_people.xlsx')

test
# Out:
#    Unnamed: 0   first        last                      email   age occupation  \
# 0           3   David         Tom         DavidTom@gmail.com   NaN      Actor
# 1           6   Jacob  Gyllenhaal   JacobGyllenhaal@mail.com  39.0        NaN
# 2           7  Maggie  Gyllenhaal  MaggieGyllenhaal@mail.com  42.0   producer
#
#   nationality               born male
# 0    American     March 23, 1978  Yes
# 1    American  December 19, 1980  Yes
# 2    American  November 16, 1977   No

# %%
american_df.to_json('american_people.json')

# %%
american_df.to_json('american_people.json', orient='records', lines=True)

# %%
test = pd.read_json('american_people.json', orient='records', lines=True)

test
# Out:
#     first        last                      email   age occupation nationality  \
# 0   David         Tom         DavidTom@gmail.com   NaN      Actor    American
# 1   Jacob  Gyllenhaal   JacobGyllenhaal@mail.com  39.0         NA    American
# 2  Maggie  Gyllenhaal  MaggieGyllenhaal@mail.com  42.0   producer    American
#
#                 born male
# 0     March 23, 1978  Yes
# 1  December 19, 1980  Yes
# 2  November 16, 1977   No

# %%
# pip install SQLAlchemy
# Out:
#   File "<ipython-input-13-96c9de2732df>", line 2
#     conda install -c anaconda psycopg2
#                 ^
# SyntaxError: invalid syntax

# %%
from sqlalchemy import create_engine
import psycopg2

# %%
# engine = create_engine('postgresql://dbuser:dbpass@localhost:5432/sample_db')

# %%
# american_df.to_sql('sample_table', engine, if_exists='replace')
# aql_df = pd.read_sql('sample_table', engine, index_col='somecolname')
# sal_df.head()
